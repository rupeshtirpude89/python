# %% [markdown]
# ## rules for assigning variables

# %%
1var=hello #nuber can be used before any alphabet for assigning variables
# Out:
#   Cell In[1], line 1
#     1var=hello
#     ^
# SyntaxError: invalid decimal literal

# %%
_var="hii" #underscrol can also be used

# %%
 =1 #space is not used in place of space underscroll can be used
# Out:
#   Cell In[6], line 1
#     =1 #space is not used in place of space underscroll can be used
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Datatypes

# %%
# There are 6 types of datatypes
1 int
2 float
3 str
4 bool
5 complex
6 None

# %% [markdown]
# ## Data structure

# %%
1 list
2 tupple
3 set 
4 dict

# %% [markdown]
# # operators

# %%
#various types of operators are used in python
1 Arthematic operators= 
+=addition
-=subtraction
*=multiplication
%=modulus

# %%
1. Arithmetic Operators
Operator Meaning
+        Addition
-        Subtraction
*        Multiplication
/        Division
//       Floor Division
%        Modulus (remainder)
**         Exponent (power)

# %% [markdown]
# ## Comparison Operators

# %%
==    Equal to
!=    Not equal to
>     Greater than
<     Less than
>=    greater than or equals to
<=    less than or equals to

# %% [markdown]
# ## logical operators

# %%
and     True if both conditions are true
or      True if at least one condition is true
not     Reverses the resul

# %% [markdown]
# ## Assignment Operators

# %%
 =
+=
-=
*=
/=
