# %%
name='rupesh'

# %%
name
# Out:
# 'rupesh'

# %%
surname='Tirpude'

# %%
print(name,surname)
# Out:
# rupesh Tirpude

# %%
a,b,c=10,20,50

# %%
a
# Out:
# 10

# %%
c
# Out:
# 50

# %%
b
# Out:
# 20

# %% [markdown]
# # Data types

# %%
int       =numeric values ||ex=0-9
string    ="value"or'value' and any number can can also be used ||ex=" }}", ' 3252adga*^&'
float     =  any decimal value ||ex=5.78, 7.99
bool      = True/ False 
complex   =   56 + 7j

# %%
a=20

# %%
a
# Out:
# 20

# %%
a,b,c=10,20,30

# %%
c
# Out:
# 30

# %% [markdown]
# # Data structures

# %%
list   = [4,5,7,7,"f",3,]

tuple  = (4,5,3,6,7,"g",0,)

set   = {2,3,4,5,"h"}

dict  = {1:"jan",2:"feb",3:"march"}

# %%
var={1,2,4,}

# %%
var
# Out:
# {1, 2, 4}

# %%
type(var)
# Out:
# set

# %%
lhs=[1,2,5,8,9,"rr"]

# %%
lhs
# Out:
# [1, 2, 5, 8, 9, 'rr']

# %%
lhs[-1]
# Out:
# 'rr'

# %%
lhs[2]
# Out:
# 5

# %%
type(lhs)
# Out:
# list

# %% [markdown]
# ## Non Itreable

# %%
1 int
2 float
3 bool ie boolean
4 complex

# %% [markdown]
# ## Itreables

# %%
1 str
2 list 
3 tuple
4 set
5 dict
